# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_hdf('train.h5')

# %%
train.shape
# Out:
# (1710756, 111)

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sorted_data = np.sort(train.iloc[:,2])  
plt.step(sorted_data, np.arange(sorted_data.size)/sorted_data.size) 
plt.title('halp')
plt.xlim(np.percentile(a,1),np.percentile(a,99))
plt.show()

# %%
colnames=list(train.columns.values)
#colnames=colnames[2:6]
for i in colnames:
    data=train.loc[train.loc[:,i].notnull(),i]
    #data=data.loc[(data>np.percentile(data,1)) & (data<np.percentile(data,99))]
    sns.distplot(data,kde=False,hist=True)
    plt.show()

# %%
colnames=list(train.columns.values)
#colnames=colnames[2:6]
for i in colnames:
    data=train.loc[train.loc[:,i].notnull(),i]
    data=data.loc[(data>np.percentile(data,1)) & (data<np.percentile(data,99))]
    sns.distplot(data,kde=False,hist=True)
    plt.show()

# %%
colnames=list(train.columns.values)
#colnames=colnames[2:6]
for i in colnames:
    data=train.loc[train.loc[:,i].notnull(),i]
    data=data.loc[(data>np.percentile(data,5)) & (data<np.percentile(data,95))]
    sns.distplot(data,kde=False,hist=True)
    plt.show()

# %%
plt.scatter(train.iloc[:,1],train.iloc[:,2])
plt.xlabel(colnames[1])
plt.ylabel(colnames[2])
plt.show()

# %%
for i in range(2,len(colnames)):
    plt.scatter(train.iloc[:,i],train.iloc[:,-1])
    plt.xlabel(colnames[i])
    plt.ylabel(colnames[-1])
    plt.show()

# %%
np.percentile(train.iloc[:,2],1)
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# nan

# %%
np.percentile(train.iloc[:,2],99)
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# nan

# %%
b=a.loc[(a>np.percentile(a,1)) & (a<np.percentile(a,99))]
